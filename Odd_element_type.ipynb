# %% [markdown]
# ![alt text](235097599-be129a03-904e-4a3e-8e4d-33900f980d72.png)

# %%
def odd_one(L):
    if (type(L[0])==type(L[1])) and (type(L[1])==type(L[2])):
        for elem in L:
            if type(elem)!=type(L[0]):
                print("if",elem)
                return type(elem)
    else:
        if (type(L[0])!= type(L[1])) and (type(L[1])== type(L[2])): # float int int int 
            print("case 1", L[0])
            return type(L[0])
        if (type(L[0])!= type(L[1])) and (type(L[1])!= type(L[2])): # int float int int 
            print("case 2", L[1])
            return type(L[1])
        if (type(L[0])== type(L[1])) and (type(L[1])!= type(L[2])): # int int float int
            print("case 3", L[2])
            return type(L[2])

 
odd_one([1,2,3.4,4,5])
# Out:
# case 3 3.4
# float

# %%
def odd_one(L):
  P = {}
  for elem in L:
    if type(elem) not in P:
      P[type(elem)] = 0
    P[type(elem)] += 1
  print(P)
  for key, value in P.items():
    if value == 1:
    #   print(P)  
      
      return key.__name__
print(odd_one([1,2,3.4,4,5]))
# Out:
# {<class 'int'>: 4, <class 'float'>: 1}
# float
