# %% [markdown]
# https://leetcode.com/problems/find-minimum-in-rotated-sorted-array/description/

# %% [markdown]
# # 153. Find Minimum in Rotated Sorted Array

# %% [markdown]
# Suppose an array of length n sorted in ascending order is rotated between 1 and n times. For example, the array nums = [0,1,2,4,5,6,7] might become:
#
# [4,5,6,7,0,1,2] if it was rotated 4 times.
# [0,1,2,4,5,6,7] if it was rotated 7 times.
# Notice that rotating an array [a[0], a[1], a[2], ..., a[n-1]] 1 time results in the array [a[n-1], a[0], a[1], a[2], ..., a[n-2]].
#
# Given the sorted rotated array nums of unique elements, return the minimum element of this array.
#
# You must write an algorithm that runs in O(log n) time.
#
#
#
# Example 1:
#
# Input: nums = [3,4,5,1,2]
# Output: 1
# Explanation: The original array was [1,2,3,4,5] rotated 3 times.
# Example 2:
#
# Input: nums = [4,5,6,7,0,1,2]
# Output: 0
# Explanation: The original array was [0,1,2,4,5,6,7] and it was rotated 4 times.
# Example 3:
#
# Input: nums = [11,13,15,17]
# Output: 11
# Explanation: The original array was [11,13,15,17] and it was rotated 4 times.
#
#
# Constraints:
#
# n == nums.length
# 1 <= n <= 5000
# -5000 <= nums[i] <= 5000
# All the integers of nums are unique.
# nums is sorted and rotated between 1 and n times.

# %% [markdown]
# # without slicing

# %%
#i need to somehow divide the list into half and process something
# send half of list to a function
# function takes two numbers, returns smaller number 
# nums = [2,1]
nums =[3,1,2]
# nums = [1,2,3,4]
def split(nums,st_idx, end_idx):
    # st_idx = 0 
    # end_idx = len(nums)-1
    if nums[st_idx]<nums[end_idx]:
        print("lil", nums[st_idx],nums[end_idx])
        return nums[st_idx]
    if st_idx==end_idx:
        return nums[end_idx]
    mid = (st_idx+end_idx)//2
    if nums[mid]>nums[end_idx]:
        return split(nums,mid+1, end_idx)
    else:
        return split(nums, st_idx, mid)

split(nums, 0, len(nums)-1)
# Out:
# 1

# %% [markdown]
# # with list slicing

# %%
# nums = [2,1]
# nums= [4,5,1,2,3]
# nums = [3,4,5,1,2]
nums = [3,1,2]
def findMin(nums):
    st_idx = 0
    end_idx = len(nums)-1
    if st_idx == end_idx:
        return nums[end_idx]
    if nums[st_idx] <= nums[end_idx]:# <= 
        return nums[0]
    
    mid = (st_idx+end_idx)//2
    
    if nums[mid]<nums[end_idx]:
        return findMin(nums[st_idx:mid+1])
    else:
        return findMin(nums[mid+1:end_idx+1])
findMin(nums)
# Out:
# 1

# %%
l = [0,1,2,3,4,5]
l[1:3]
# Out:
# [1, 2]
