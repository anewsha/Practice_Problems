# %% [markdown]
# [leetcode.com/problems/two-sum/description/](https://leetcode.com/problems/two-sum/description/)

# %% [markdown]
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# You can return the answer in any order.
#
#
#
# Example 1:
#
# Input: nums = [2,7,11,15], target = 9
# Output: [0,1]
# Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
# Example 2:
#
# Input: nums = [3,2,4], target = 6
# Output: [1,2]
# Example 3:
#
# Input: nums = [3,3], target = 6
# Output: [0,1]
#
#
# Constraints:
#
# 2 <= nums.length <= 104
# -109 <= nums[i] <= 109
# -109 <= target <= 109
# Only one valid answer exists.

# %%
def twoSum(nums, target):
    for i in range(len(nums)):
        for j in range(i+1, len(nums)):
            if nums[i]+nums[j]==target:
                return [i,j]
nums = [2,3,4,8]
target = 6
twoSum(nums, target)
# Out:
# [0, 2]

# %%
def twoSum(nums, target):
    my_dict ={}
    for i in range(len(nums)):
        if (target-nums[i]) in my_dict:
            return [my_dict[target-nums[i]], i]
        my_dict[nums[i]]=i

nums = [3,3]
target = 6
twoSum(nums, target)
# Out:
# [0, 1]

# %% [markdown]
# what if I want to find all pairs

# %%
l = [1,5,5,1,2,4]

# %%
def twoSum(nums, target: int):
    my_dict ={}
    answer_list = []
    for i in range(len(nums)):
        if (target-nums[i]) in my_dict:
            answer_list.append([nums[i], target-nums[i]])
        my_dict[nums[i]]=i
    answer_final = set()
    for l in answer_list:
        answer_final.add(tuple(sorted(l)))
    return answer_final

# %%
twoSum(l,6)
# Out:
# {(1, 5), (2, 4)}

# %%
t = [[5, 1], [4, 2], [1, 5]]
lst = set()
# Out:
# False
# True

# %%
set
