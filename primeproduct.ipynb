# %% [markdown]
# ### Write a Python function primeproduct(m) that takes an integer m as input and returns True if m is a prime product (i.e., can be written as p * q, where both p and q are prime numbers), and False otherwise. If m is not positive, the function should return False.

# %%
'''
def is_prime(int: n):
isprime=true
for i in range(n/2+1):
if n%i==0:
break --> return false (not prime)

def main(m):
candidate_primes =[]
flag=False
for i in range(m):
if is_prime(i):
    if m/i in candidate_primes:
        return True
    candidate_primes.append(i)
    


'''
# Out:
# '\ndef is_prime(int: n):\nif \n'

# %%
def is_prime(n):
    if n<=1:
        return False
    primes = []
    for i in range(2,n//2 +1):
        if n%i==0:
            primes.append(i)
    # return True
    return primes
# print(is_prime(12))

def main(m):
    candidate_primes = is_prime(m)
    flag = False
    for i in range(1,m):
        if int(m/i) in candidate_primes:
            print(candidate_primes)
            return True
        # candidate_primes.append(i)
    return False

print(main(6))
# Out:
# [2, 3]
# True

# %%
int(4/2)
# Out:
# 2
