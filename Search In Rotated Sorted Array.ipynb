# %% [markdown]
# https://leetcode.com/problems/search-in-rotated-sorted-array/description/

# %% [markdown]
# # 33. Search in Rotated Sorted Array

# %% [markdown]
# There is an integer array nums sorted in ascending order (with distinct values).
#
# Prior to being passed to your function, nums is possibly left rotated at an unknown index k (1 <= k < nums.length) such that the resulting array is [nums[k], nums[k+1], ..., nums[n-1], nums[0], nums[1], ..., nums[k-1]] (0-indexed). For example, [0,1,2,4,5,6,7] might be left rotated by 3 indices and become [4,5,6,7,0,1,2].
#
# Given the array nums after the possible rotation and an integer target, return the index of target if it is in nums, or -1 if it is not in nums.
#
# You must write an algorithm with O(log n) runtime complexity.
#
#
#
# Example 1:
#
# Input: nums = [4,5,6,7,0,1,2], target = 0
# Output: 4
# Example 2:
#
# Input: nums = [4,5,6,7,0,1,2], target = 3
# Output: -1
# Example 3:
#
# Input: nums = [1], target = 0
# Output: -1
#
#
# Constraints:
#
# 1 <= nums.length <= 5000
# -104 <= nums[i] <= 104
# All values of nums are unique.
# nums is an ascending array that is possibly rotated.
# -104 <= target <= 104

# %%
# nums = [4,5,6,7,0,1,2]
# nums = [1,2]
nums = [6,7,8,1,2,3,4,5]
# problem is, unlike in search in normal sorted array, here i cant discard any half of the array. 
# but what if i am able to check the lowest index, then i can discard. 
def search(nums, st_idx, end_idx,target):
    # st_idx = 0
    # end_idx = len(nums)-1
    mid = (st_idx+end_idx )//2
    if nums[mid]==target:
        return mid
    if st_idx>=end_idx:
        return -1
    
    if nums[mid]>target:#
        if nums[st_idx]>target:
            return search(nums, mid+1,end_idx,target)#
        if nums[st_idx]<target: #else
            return search(nums,st_idx,mid, target)
    else:#
        if nums[end_idx]<=target:
            return search(nums,mid+1,end_idx, target)#x
        else:
            return search(nums,st_idx,mid, target)

search(nums,0, len(nums)-1,8)
# Out:
# -1

# %%
# nums = [4,5,6,7,0,1,2]
# nums = [1,2]
nums = [6,7,8,1,2,3,4,5]

# problem is, unlike in search in normal sorted array, here i cant discard any half of the array. 
# but what if i am able to check the lowest index, then i can discard. 
def search_rec(nums, st_idx, end_idx,target):
    # st_idx = 0
    # end_idx = len(nums)-1
    mid = (st_idx+end_idx )//2
    if nums[mid]==target:
        return mid
    if st_idx>=end_idx:
        return -1

    # if nums[st_idx]<nums[mid]:
    #     # left is sorted
    #     return search(nums, st_idx, mid,target)
   # left sorted if start MID 
    if nums[st_idx]<=nums[mid]:
        if nums[st_idx]<=target and target <nums[mid]:
            print("left srt mid = ", nums[mid])
            return search(nums, st_idx, mid-1,target)
        else:
            print("left sort but target in right, mid = ", nums[mid])
            return search(nums, mid+1, end_idx, target)
    else:
        if nums[mid]<target<=nums[end_idx]:
            print("right sort and present in right,  mid = ", nums[mid])
            return search(nums, mid+1, end_idx, target)
        else:
            print("right sort and prsent in left,  mid = ", nums[mid])
            return search(nums, st_idx, mid-1, target)

   #right sorted if mid END 
    
search(nums,0, len(nums)-1,2)
# Out:
# right sort and present in right,  mid =  1
# left srt mid =  3
# 4
