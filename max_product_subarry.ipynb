# %% [markdown]
# https://leetcode.com/problems/maximum-product-subarray/description/

# %%
print(1)
# Out:
# 1

# %% [markdown]
# # 152. Maximum Product Subarray
#
# Given an integer array nums, find a subarray that has the largest product, and return the product.
#
# The test cases are generated so that the answer will fit in a 32-bit integer.
#
# Note that the product of an array with a single element is the value of that element.
#
#
#
# Example 1:
#
# Input: nums = [2,3,-2,4]
# Output: 6
# Explanation: [2,3] has the largest product 6.
# Example 2:
#
# Input: nums = [-2,0,-1]
# Output: 0
# Explanation: The result cannot be 2, because [-2,-1] is not a subarray.
#
#
# Constraints:
#
# 1 <= nums.length <= 2 * 104
# -10 <= nums[i] <= 10
# The product of any subarray of nums is guaranteed to fit in a 32-bit integer.

# %%
nums = [-3,0,1,-2]
# nums = [2,3,-2,4]
def maxProduct(nums) -> int:
    max_prod = nums[0] #0
    for i in range(0,len(nums)): 
        prod_inner = nums[i]  #3
        max_prod = max(max_prod, prod_inner)
        for j in range(i+1,len(nums)):
            prod_inner = prod_inner * nums[j]
            max_prod = max(max_prod, prod_inner)
        max_prod = max(max_prod, prod_inner)
        
    return max_prod

maxProduct(nums)
# Out:
# 1

# %%
for i in range(3,4):
    print("hi")
# Out:
# hi

# %%
# nums = [2,3,-2,4]
# nums = [ 2,3 ,0, 2,4]
# nums = [0]
# nums = [0,2]
# nums = [0,-2]
nums = [-1]

# thought: till "i", if the array has to END here, whats the max prod?
# encounter 0?? => reset everything.
# prolly need to maintain a global max prod (update before 0 and after 0 subarray situations)
# 
main_max = float("-inf")
min_prod_at_i = 1
max_prod_at_i = 1
for i in range(len(nums)):
    min_prod = min_prod_at_i*nums[i]
    max_prod = max_prod_at_i * nums[i]
    min_prod_at_i = min(nums[i],min_prod, max_prod) # 2, 6, -12, -48
    print(f"min at {i} :", min_prod_at_i)
    max_prod_at_i = max(nums[i],min_prod, max_prod)
    print(f"MAX at {i} :", max_prod_at_i)
    main_max = max(min_prod_at_i, max_prod_at_i,main_max)
print(main_max)
# Out:
# min at 0 : -1
# MAX at 0 : -1
# -1
